# %% [markdown]
# # **Synchronize video files**

# %% [markdown]
# First we create the motif that we want to use for the synchronization process, in our case, the blink pattern of the LED.
# The motif is generated as a kind of ground truth with a resolution of 1 ms (could be made adaptable, though). Upon loading
# the motif template into a single cam data object, it will create all possible timeseries that could be observed, given the
# framerate of the respective camera & the resolution of the template.

# %%
from gait3d.sync_videos import MotifTemplate, MultiMotifTemplate

#no_blinking_template = MotifTemplate(led_on_time_in_ms=0, on_off_period_length_in_ms=100, motif_duration_in_ms=200)
regular_blinking_template = MotifTemplate(led_on_time_in_ms=50, on_off_period_length_in_ms=1_000, motif_duration_in_ms=4_000)
fast_blinking_template = MotifTemplate(led_on_time_in_ms=50, on_off_period_length_in_ms=100, motif_duration_in_ms=3_000)

# %%
combined_template = MultiMotifTemplate()

# %%
combined_template.add_motif_template(fast_blinking_template)
combined_template.add_motif_template(regular_blinking_template)

# %%
import matplotlib.pyplot as plt

plt.plot(combined_template.multi_motif_template)

# %% [markdown]
# Now that we have our template ready, let´s load the actual video file & construct our single cam data object!
# Please note, since there is no DLC tracking data of the LED available as of yet, LED positions are hardcoded
# and can be specified using the "led_marker_id" argument. Initializing the `cam_raw_calib_data` object might
# take quite some time, as the LED pixel intensities have to be extracted from each & every frame of the video!

# %%
from pathlib import Path

filepath_video = Path('/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/calibration_top_nocrop002.AVI')

# %%
from gait3d.sync_videos import SingleCamRawCalibrationData

cam_raw_calib_data = SingleCamRawCalibrationData(filepath_video = filepath_video,
                                                 filepath_tracking = 'n.a.',
                                                 led_marker_id = 'top_nocrop')

# %%
import matplotlib.pyplot as plt

plt.plot(cam_raw_calib_data.led_timeseries)
plt.xlim(0, 400)
# Out:
# (0.0, 400.0)

# %% [markdown]
# Another to-be-properly-implemented-step:
#
# The fps are saved as 160 in the metadata of the video files. However, frame capturing was deliberately triggered only at 125 fps.
# This either has to be updated alread in the video files (ideally?), or become an argument of the method / or become hardcoded.
# For now, we simply do it here:

# %%
if cam_raw_calib_data.fps == 60:
    cam_raw_calib_data.fps = 30

# %% [markdown]
# Time to see whether we can find a match of our template! You can use the `start_time` and `end_time` arguments to specify
# the interval (in ms) in which the alignment should be checked. This might be usefull, as a pattern could occur multiple times
# in a single session but maybe you want to align to a specific occurance of the motif, rather than to the best match, i.e.
# for synchronization maybe only in a 20 s window right of the start?
#
# In the created plot, blue represents the LED pixel intensity timeseries & orange the fps adjusted template motif with the offset
# that results in the best alignment score. The top graph shows the raw data values (i.e. pixel intensities or binary 0 / 1,
# respectively). The lower graph shows the z-score normalized data, which is also used for calculating the alignment score.

# %%
best_match_offset, best_match_start_idx = cam_raw_calib_data.find_best_match_of_template(template=combined_template, end_time = 20_000)

# %% [markdown]
# If the alignment looks good (crisp & near perfect alignment of vertical lines - amplitude is not relevant), you can proceed and adjust your video to this synchronization. Using `target_fps`,
# you also have the option to downsample the video accordingly

# %%
cam_raw_calib_data.write_synchronized_and_fps_adjusted_calibration_video(start_frame_idx = best_match_start_idx, offset = best_match_offset, target_fps = 30, max_frame_count = 1_000)
# Out:
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# load original video
# writing video to disk
# done!
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 402 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 399 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 527 kb/s
#     Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 524 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 445 kb/s
#     Stream #2:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 443 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 477 kb/s
#     Stream #3:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 475 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #4, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_004.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 317 kb/s
#     Stream #4:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 315 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #5, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_005.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 504 kb/s
#     Stream #5:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 502 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #6, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_006.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 576 kb/s
#     Stream #6:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 573 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #7, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_007.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 501 kb/s
#     Stream #7:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 499 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #8, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_008.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.33, start: 0.000000, bitrate: 483 kb/s
#     Stream #8:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 480 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #9, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_part_009.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:04.83, start: 0.000000, bitrate: 139 kb/s
#     Stream #9:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 135 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   Stream #2:0 (h264) -> concat:in1:v0
#   Stream #3:0 (h264) -> concat:in1:v0
#   Stream #4:0 (h264) -> concat:in1:v0
#   Stream #5:0 (h264) -> concat:in1:v0
#   Stream #6:0 (h264) -> concat:in1:v0
#   Stream #7:0 (h264) -> concat:in1:v0
#   Stream #8:0 (h264) -> concat:in1:v0
#   Stream #9:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ba5bd84400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ba5bd84400] profile High, level 3.0
# [libx264 @ 0x55ba5bd84400] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/mnt/c/Users/dsege/Downloads/OneDrive_2022-08-18/Setup_Test_220818/top_nocrop_cam_synchronized_for_calibration_all_parts.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 9145 fps=468 q=-1.0 Lsize=   15349kB time=00:05:04.73 bitrate= 412.6kbits/s speed=15.6x
# video:15250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.652060%
# [libx264 @ 0x55ba5bd84400] frame I:37    Avg QP:18.53  size: 21700
# [libx264 @ 0x55ba5bd84400] frame P:3522  Avg QP:22.20  size:  3330
# [libx264 @ 0x55ba5bd84400] frame B:5586  Avg QP:26.64  size:   552
# [libx264 @ 0x55ba5bd84400] consecutive B-frames: 10.5% 18.3% 17.6% 53.6%
# [libx264 @ 0x55ba5bd84400] mb I  I16..4: 12.5% 71.8% 15.7%
# [libx264 @ 0x55ba5bd84400] mb P  I16..4:  1.4%  2.5%  0.2%  P16..4: 39.0% 11.0%  5.0%  0.0%  0.0%    skip:41.0%
# [libx264 @ 0x55ba5bd84400] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 24.1%  1.4%  0.2%  direct: 0.2%  skip:73.9%  L0:40.3% L1:55.3% BI: 4.3%
# [libx264 @ 0x55ba5bd84400] 8x8 transform intra:63.9% inter:80.1%
# [libx264 @ 0x55ba5bd84400] coded y,uvDC,uvAC intra: 37.6% 46.4% 13.9% inter: 7.1% 7.5% 0.2%
# [libx264 @ 0x55ba5bd84400] i16 v,h,dc,p: 27% 17% 10% 46%
# [libx264 @ 0x55ba5bd84400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 15% 32%  4%  4%  4%  5%  5%  4%
# [libx264 @ 0x55ba5bd84400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 22% 15%  5%  6%  5%  7%  5%  5%
# [libx264 @ 0x55ba5bd84400] i8c dc,h,v,p: 58% 16% 23%  3%
# [libx264 @ 0x55ba5bd84400] Weighted P-Frames: Y:0.2% UV:0.0%
# [libx264 @ 0x55ba5bd84400] ref P L0: 69.1% 16.7% 11.2%  3.0%  0.0%
# [libx264 @ 0x55ba5bd84400] ref B L0: 90.8%  7.8%  1.4%
# [libx264 @ 0x55ba5bd84400] ref B L1: 97.9%  2.1%
# [libx264 @ 0x55ba5bd84400] kb/s:409.79
