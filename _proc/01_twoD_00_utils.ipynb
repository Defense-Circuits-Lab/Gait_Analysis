# %% [raw]
# ---
# description: Basic functions used throughout the 2D module and/or that foster the
#   use of this module
# output-file: twod_utils.html
# title: utility functions for two dimensional gait analyses
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(process_all_dlc_tracking_h5s_with_default_settings)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_all_dlc_tracking_h5s_with_default_settings
#
# >      process_all_dlc_tracking_h5s_with_default_settings
# >                                                          (in_dir_path:pathlib.
# >                                                          Path, week_id:int, ou
# >                                                          t_dir_path:pathlib.Pa
# >                                                          th)
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | in_dir_path | Path | path to the input directory which contains all DLC tracking data results |
# | week_id | int | number of weeks post injection |
# | out_dir_path | Path | path to the output directory where all processed results will be saved |
# | **Returns** | **None** |  |

# %% [markdown]
# ## Functions related to preprocessing:

# %%
#| echo: false
#| output: asis
show_doc(get_max_odd_n_frames_for_time_interval)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_max_odd_n_frames_for_time_interval
#
# >      get_max_odd_n_frames_for_time_interval (fps:int, time_interval:0.5)
#
# For the savgol_filter function of scipy - which will be used during preprocessing to smooth the data -
# you need an odd integer as the window_length parameter. This function helps to find the maximum odd number
# of frames that still fit within a specified time interval at a given fps.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | fps | int | frames per second of the recording |
# | time_interval | 0.5 | desired maximal time interval in seconds; default = 0.5 s |
# | **Returns** | **int** |  |

# %%
#| echo: false
#| output: asis
show_doc(get_preprocessing_relevant_marker_ids)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_preprocessing_relevant_marker_ids
#
# >      get_preprocessing_relevant_marker_ids (df:pandas.core.frame.DataFrame,
# >                                             marker_ids_to_exclude:Union[List[s
# >                                             tr],NoneType]=None)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | df | DataFrame |  | DataFrame with x, y, and likelihood for tracked marker_ids |
# | marker_ids_to_exclude | typing.Union[typing.List[str], NoneType] | None | list of marker_ids to exclude; optional default None |
# | **Returns** | **typing.List[str]** |  |  |

# %%
#| echo: false
#| output: asis
show_doc(get_all_unique_marker_ids)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L90){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_all_unique_marker_ids
#
# >      get_all_unique_marker_ids (df:pandas.core.frame.DataFrame)

# %%
#| echo: false
#| output: asis
show_doc(smooth_tracked_coords_and_likelihood)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### smooth_tracked_coords_and_likelihood
#
# >      smooth_tracked_coords_and_likelihood (df:pandas.core.frame.DataFrame,
# >                                            window_length:int,
# >                                            marker_ids:List[str]=['all'],
# >                                            polyorder:int=3)
#
# Smoothes the DataFrame basically using the implementation from DLC2kinematics:
# https://github.com/AdaptiveMotorControlLab/DLC2Kinematics/blob/82e7e60e00e0efb3c51e024c05a5640c91032026/src/dlc2kinematics/preprocess.py#L64
# However, with one key change: likelihoods will also be smoothed.
# In addition, we will not smooth the columns for the tracked LEDs and the MazeCorners.
#
# Note: window_length has to be an odd integer!
#
# |    | **Type** | **Default** | **Details** |
# ...

# %%
#| echo: false
#| output: asis
show_doc(get_column_names)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L131){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_column_names
#
# >      get_column_names (df:pandas.core.frame.DataFrame,
# >                        column_identifiers:List[str],
# >                        marker_ids:List[str]=['all'])

# %%
#| echo: false
#| output: asis
show_doc(interpolate_low_likelihood_intervals)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L148){target="_blank" style="float:right; font-size:smaller"}
#
# ### interpolate_low_likelihood_intervals
#
# >      interpolate_low_likelihood_intervals (df:pandas.core.frame.DataFrame,
# >                                            marker_ids:List[str],
# >                                            max_interval_length:int,
# >                                            framerate:float)

# %%
#| echo: false
#| output: asis
show_doc(get_low_likelihood_interval_border_idxs)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L179){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_low_likelihood_interval_border_idxs
#
# >      get_low_likelihood_interval_border_idxs
# >                                               (likelihood_series:pandas.core.s
# >                                               eries.Series, framerate:float,
# >                                               max_interval_length:int, min_lik
# >                                               elihood_threshold:float=0.5)

# %%
#| echo: false
#| output: asis
show_doc(get_interval_border_idxs)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L196){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_interval_border_idxs
#
# >      get_interval_border_idxs (all_matching_idxs:numpy.ndarray,
# >                                framerate:float, min_interval_duration:Union[fl
# >                                oat,NoneType]=None, max_interval_duration:Union
# >                                [float,NoneType]=None)

# %%
#| echo: false
#| output: asis
show_doc(add_new_marker_derived_from_existing_markers)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L229){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_new_marker_derived_from_existing_markers
#
# >      add_new_marker_derived_from_existing_markers
# >                                                    (df:pandas.core.frame.DataF
# >                                                    rame,
# >                                                    existing_markers:List[str],
# >                                                    new_marker_id:str, likeliho
# >                                                    od_threshold:float=0.5)

# %%
#| echo: false
#| output: asis
show_doc(get_idxs_where_all_markers_exceed_likelihood)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L255){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_idxs_where_all_markers_exceed_likelihood
#
# >      get_idxs_where_all_markers_exceed_likelihood
# >                                                    (df:pandas.core.frame.DataF
# >                                                    rame, marker_ids:List[str],
# >                                                    likelihood_threshold:float=
# >                                                    0.5)

# %%
#| echo: false
#| output: asis
show_doc(compute_coverage)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L272){target="_blank" style="float:right; font-size:smaller"}
#
# ### compute_coverage
#
# >      compute_coverage (df:pandas.core.frame.DataFrame,
# >                        critical_marker_ids:List[str],
# >                        likelihood_threshold:float=0.5)

# %%
#| echo: false
#| output: asis
show_doc(get_corner_coords_with_likelihoods)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L285){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_corner_coords_with_likelihoods
#
# >      get_corner_coords_with_likelihoods (df:pandas.core.frame.DataFrame)

# %%
#| echo: false
#| output: asis
show_doc(get_most_reliable_marker_position_with_likelihood)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L303){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_most_reliable_marker_position_with_likelihood
#
# >      get_most_reliable_marker_position_with_likelihood
# >                                                         (df:pandas.core.frame.
# >                                                         DataFrame,
# >                                                         marker_id:str, percent
# >                                                         ile:float=99.95)

# %%
#| echo: false
#| output: asis
show_doc(get_translation_vector)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L319){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_translation_vector
#
# >      get_translation_vector (coords_to_become_origin:numpy.ndarray)

# %%
#| echo: false
#| output: asis
show_doc(evaluate_maze_shape_using_open_corners)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L323){target="_blank" style="float:right; font-size:smaller"}
#
# ### evaluate_maze_shape_using_open_corners
#
# >      evaluate_maze_shape_using_open_corners (corners_and_likelihoods:Dict,
# >                                              tolerance:float)

# %%
#| echo: false
#| output: asis
show_doc(compute_error_proportion)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L366){target="_blank" style="float:right; font-size:smaller"}
#
# ### compute_error_proportion
#
# >      compute_error_proportion (query_value:float, target_value:float)

# %%
#| echo: false
#| output: asis
show_doc(compute_angle_error)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L370){target="_blank" style="float:right; font-size:smaller"}
#
# ### compute_angle_error
#
# >      compute_angle_error (a:numpy.ndarray, b:numpy.ndarray, c:numpy.ndarray)

# %%
#| echo: false
#| output: asis
show_doc(compute_distance_ratio_error)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L379){target="_blank" style="float:right; font-size:smaller"}
#
# ### compute_distance_ratio_error
#
# >      compute_distance_ratio_error (corners_and_likelihoods:Dict,
# >                                    open_corner_marker_id:str, side_id:str)

# %%
#| echo: false
#| output: asis
show_doc(get_distance_between_two_points)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L394){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_distance_between_two_points
#
# >      get_distance_between_two_points (coords_point_a:numpy.ndarray,
# >                                       coords_point_b:numpy.ndarray)

# %%
#| echo: false
#| output: asis
show_doc(get_conversion_factor_px_to_cm)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L403){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_conversion_factor_px_to_cm
#
# >      get_conversion_factor_px_to_cm (coords_point_a:numpy.ndarray,
# >                                      coords_point_b:numpy.ndarray,
# >                                      distance_in_cm:float)

# %%
#| echo: false
#| output: asis
show_doc(get_rotation_angle_with_open_corner)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L410){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_rotation_angle_with_open_corner
#
# >      get_rotation_angle_with_open_corner (corners:Dict, side_id:str,
# >                                           translation_vector:numpy.ndarray,
# >                                           conversion_factor:float)
#
# Function, that calculates the rotation angle of the maze considering the best matching open corner
# and the corresponding closed corner on the same side.
#
# Returns:
#     float: angle in radians

# %%
#| echo: false
#| output: asis
show_doc(get_rotation_angle_with_closed_corners_only)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L455){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_rotation_angle_with_closed_corners_only
#
# >      get_rotation_angle_with_closed_corners_only (corners:Dict,
# >                                                   translation_vector:numpy.nda
# >                                                   rray,
# >                                                   conversion_factor:float)

# %%
#| echo: false
#| output: asis
show_doc(normalize_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L483){target="_blank" style="float:right; font-size:smaller"}
#
# ### normalize_df
#
# >      normalize_df (df:pandas.core.frame.DataFrame, normalization_parameters)

# %%
#| echo: false
#| output: asis
show_doc(translate_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L499){target="_blank" style="float:right; font-size:smaller"}
#
# ### translate_df
#
# >      translate_df (df:pandas.core.frame.DataFrame, translation_vector:<built-
# >                    infunctionarray>)

# %%
#| echo: false
#| output: asis
show_doc(rotate_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L505){target="_blank" style="float:right; font-size:smaller"}
#
# ### rotate_df
#
# >      rotate_df (df:pandas.core.frame.DataFrame, rotation_angle:float)
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | df | DataFrame | DataFrame with 2D coordinates to be rotated |
# | rotation_angle | float | rotation angle in radians |
# | **Returns** | **DataFrame** |  |

# %%
#| echo: false
#| output: asis
show_doc(convert_df_to_cm)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/utils.py#L521){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_df_to_cm
#
# >      convert_df_to_cm (df:pandas.core.frame.DataFrame,
# >                        conversion_factor:float)
