# %% [raw]
# ---
# description: Analysis of DLC tracking data of top camera recordings
# output-file: twod_topcam.html
# title: 2D gait analysis of top cam data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Tracked2DRecording)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/topcam.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### Tracked2DRecording
#
# >      Tracked2DRecording (filepath:pathlib.Path, week_id:int)
#
# Very customized subclass of `TrackedRecording` that was designed to run the gait analysis
# on 2D tracking data obtained from a single camera with a top-down-view on the subject.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | filepath | Path | the filepath to the output of DLC (.h5 or .csv file) |
# | week_id | int | the experimental week post injection in which the recording was performed. Has to be an element of the self.valid_week_ids list |
# | **Returns** | **None** |  |

# %%
#| echo: false
#| output: asis
show_doc(Bodypart2D)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/topcam.py#L295){target="_blank" style="float:right; font-size:smaller"}
#
# ### Bodypart2D
#
# >      Bodypart2D (bodypart_id:str, df:pandas.core.frame.DataFrame, fps:int)
#
# Class that contains information for one single Bodypart.
#
# Attributes:
#     self.id(str): Deeplabcut label of the bodypart
