# %% [raw]
# ---
# description: Functions specifically related to event detection of 2D recordings
# output-file: twod_detect.html
# title: twoD/detect
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(create_behavior_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_behavior_df
#
# >      create_behavior_df (normalized_df:pandas.core.frame.DataFrame,
# >                          bodyparts_to_include:List[str])

# %%
#| echo: false
#| output: asis
show_doc(add_orientation_to_behavior_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_orientation_to_behavior_df
#
# >      add_orientation_to_behavior_df (behavior_df:pandas.core.frame.DataFrame,
# >                                      all_bodyparts:Dict, bodyparts_for_directi
# >                                      on_front_to_back:List[str])

# %%
#| echo: false
#| output: asis
show_doc(add_immobility_based_on_several_bodyparts_to_behavior_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_immobility_based_on_several_bodyparts_to_behavior_df
#
# >      add_immobility_based_on_several_bodyparts_to_behavior_df
# >                                                                (behavior_df:pa
# >                                                                ndas.core.frame
# >                                                                .DataFrame, all
# >                                                                _bodyparts:Dict
# >                                                                , bodyparts_cri
# >                                                                tical_for_freez
# >                                                                ing:List[str])

# %%
#| echo: false
#| output: asis
show_doc(get_immobility_related_events)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_immobility_related_events
#
# >      get_immobility_related_events (behavior_df:pandas.core.frame.DataFrame,
# >                                     fps:float, min_interval_duration:float,
# >                                     event_type:str)

# %%
#| echo: false
#| output: asis
show_doc(create_event_objects)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L88){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_event_objects
#
# >      create_event_objects (interval_border_idxs:List[Tuple[int,int]], fps:int,
# >                            event_type:str)

# %%
#| echo: false
#| output: asis
show_doc(add_event_bouts_to_behavior_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L106){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_event_bouts_to_behavior_df
#
# >      add_event_bouts_to_behavior_df (behavior_df:pandas.core.frame.DataFrame,
# >                                      event_type:str, events:List[gait_analysis
# >                                      .core.EventBout])

# %%
#| echo: false
#| output: asis
show_doc(get_gait_events)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L130){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_gait_events
#
# >      get_gait_events (all_bodyparts:Dict, fps:int,
# >                       gait_min_rolling_speed:float, gait_min_duration:float)

# %%
#| echo: false
#| output: asis
show_doc(get_gait_disruption_events)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L151){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_gait_disruption_events
#
# >      get_gait_disruption_events (behavior_df:pandas.core.frame.DataFrame,
# >                                  fps:int, gait_events:List[gait_analysis.core.
# >                                  EventBout],
# >                                  gait_disruption_max_time_to_immobility:float)

# %%
#| echo: false
#| output: asis
show_doc(get_interval_border_idxs_from_event_type_and_id)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/detect.py#L189){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_interval_border_idxs_from_event_type_and_id
#
# >      get_interval_border_idxs_from_event_type_and_id
# >                                                       (behavior_df:pandas.core
# >                                                       .frame.DataFrame,
# >                                                       event_type:str,
# >                                                       event_id:int)
