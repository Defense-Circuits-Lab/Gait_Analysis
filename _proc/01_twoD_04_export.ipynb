# %% [raw]
# ---
# description: Functions specifically related to exporting the analysis results of 2D
#   recordings
# output-file: twod_export.html
# title: twoD/export
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(export_immobility_related_bouts)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### export_immobility_related_bouts
#
# >      export_immobility_related_bouts (df:pandas.core.frame.DataFrame,
# >                                       event_type:str, framerate:float)

# %%
#| echo: false
#| output: asis
show_doc(get_all_bout_ids)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_all_bout_ids
#
# >      get_all_bout_ids (df:pandas.core.frame.DataFrame, event_type:str)

# %%
#| echo: false
#| output: asis
show_doc(get_bout_duration_per_bout_id)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_bout_duration_per_bout_id
#
# >      get_bout_duration_per_bout_id (df:pandas.core.frame.DataFrame,
# >                                     event_type:str, event_ids:List[float])

# %%
#| echo: false
#| output: asis
show_doc(get_column_values_at_event_borders)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L86){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_column_values_at_event_borders
#
# >      get_column_values_at_event_borders (df:pandas.core.frame.DataFrame,
# >                                          event_type:str,
# >                                          event_ids:List[float],
# >                                          column_name:str)

# %%
#| echo: false
#| output: asis
show_doc(get_distance_covered_per_event)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L97){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_distance_covered_per_event
#
# >      get_distance_covered_per_event (df:pandas.core.frame.DataFrame,
# >                                      event_type:str, event_ids:List[float],
# >                                      marker_id:str)

# %%
#| echo: false
#| output: asis
show_doc(get_interval_start_and_end_time_per_event)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L117){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_interval_start_and_end_time_per_event
#
# >      get_interval_start_and_end_time_per_event
# >                                                 (df:pandas.core.frame.DataFram
# >                                                 e, event_type:str,
# >                                                 event_ids:List[float],
# >                                                 framerate:float)

# %%
#| echo: false
#| output: asis
show_doc(export_gait_related_bouts)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L129){target="_blank" style="float:right; font-size:smaller"}
#
# ### export_gait_related_bouts
#
# >      export_gait_related_bouts (df:pandas.core.frame.DataFrame,
# >                                 event_type:str, framerate:float)

# %%
#| echo: false
#| output: asis
show_doc(create_session_overview_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L184){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_session_overview_df
#
# >      create_session_overview_df (dfs_to_export_with_individual_bout_dfs:Dict[s
# >                                  tr,pandas.core.frame.DataFrame])

# %%
#| echo: false
#| output: asis
show_doc(get_bout_id_splits_depending_on_direction)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L214){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_bout_id_splits_depending_on_direction
#
# >      get_bout_id_splits_depending_on_direction
# >                                                 (df:pandas.core.frame.DataFram
# >                                                 e)

# %%
#| echo: false
#| output: asis
show_doc(get_column_name_from_substring)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L232){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_column_name_from_substring
#
# >      get_column_name_from_substring (all_columns:List[str], substring:str)

# %%
#| echo: false
#| output: asis
show_doc(add_results_to_session_overview)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L242){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_results_to_session_overview
#
# >      add_results_to_session_overview (session_overview:Dict,
# >                                       df:pandas.core.frame.DataFrame,
# >                                       event_type:str, event_prefix:str,
# >                                       bout_ids:List[float])

# %%
#| echo: false
#| output: asis
show_doc(create_parameter_settings_df)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_parameter_settings_df
#
# >      create_parameter_settings_df (logs:Dict)

# %%
#| echo: false
#| output: asis
show_doc(write_xlsx_file_to_disk)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/Gait_Analysis/blob/main/gait_analysis/twoD/export.py#L290){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_xlsx_file_to_disk
#
# >      write_xlsx_file_to_disk (base_output_filepath:pathlib.Path,
# >                               dfs_to_export:Dict[str,pandas.core.frame.DataFra
# >                               me])
